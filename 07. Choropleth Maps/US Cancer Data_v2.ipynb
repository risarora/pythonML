# %%
#import the packages
import pandas as pd
import numpy as np 
#%matplotlib inline
import plotly as ps
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot 
init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
exportData = pd.read_csv('C:/Users/rarora17/Desktop/Hackathon/model_data_with_population_ratio_v2.csv')
exportData.head()
# Out:
#    year LocationDesc StateCode  Percentage of smokers number  Lung_Cancer  \
# 0  2011      Alabama        AL                          24.3         4240
# 1  2011       Alaska        AK                          22.9          380
# 2  2011      Arizona        AZ                          19.3         3820
# 3  2011     Arkansas        AR                          27.0         2660
# 4  2011   California        CA                          13.7        17660
#
#          NO2        O3       SO2        CO  Cancer rate PER 10000 people  \
# 0  14.957035  0.026975  0.923327  0.369351                      8.833484
# 1  13.298735  0.027137  1.070729  0.395276                      5.257965
# 2  16.615336  0.026813  0.775925  0.343425                      5.906763
# 3   9.982134  0.027461  1.365533  0.447127                      9.049180
# 4  12.282852  0.026144  0.709326  0.360517                      4.687227
#
#    Total Population in the Year
# 0                       4799918
# 1                        722713
# 2                       6467163
# 3                       2939493
# 4                      37676861

# %%
Year2011 = exportData.loc[exportData['year'] == 2011]
Year2011.tail()
# Out:
#     year   LocationDesc StateCode  Percentage of smokers number  Lung_Cancer  \
# 45  2011       Virginia        VA                          20.9          400
# 46  2011     Washington        WA                          17.5         3090
# 47  2011  West Virginia        WV                          28.6         1480
# 48  2011      Wisconsin        WI                          20.9         2940
# 49  2011        Wyoming        WY                          23.0          260
#
#          NO2        O3       SO2        CO  Cancer rate PER 10000 people  \
# 45  7.925900  0.033164  0.614729  0.289210                      0.493216
# 46       NaN       NaN       NaN       NaN                      4.529118
# 47       NaN       NaN       NaN       NaN                      7.978557
# 48       NaN       NaN       NaN       NaN                      5.149186
# 49  4.168866  0.037890  0.164214  0.123083                      4.579682
#
#     Total Population in the Year
# 45                       8110035
# 46                       6822520
# 47                       1854972
# 48                       5709640
# 49                        567725

# %%
Year2011 = exportData.loc[exportData['year'] == 2011]
Year2011['Cancer rate PER 10000 people'].head()
# Out:
# 0    8.833484
# 1    5.257965
# 2    5.906763
# 3    9.049180
# 4    4.687227
# Name: Cancer rate PER 10000 people, dtype: float64

# %%
Year2011 = exportData.loc[exportData['year'] == 2011]

plot2011_Pollution = dict(type ='choropleth',
           locations = exportData['StateCode'],
           locationmode = 'USA-states',
           colorscale = 'YlOrRd_r',
           text=Year2011['Lung_Cancer'],
           z = Year2011['Cancer rate PER 10000 people'],
           marker = dict(line=dict(color='rgb(255,255,255)',width=1)),
           colorbar = {'title':'Cancer Rates'})
myLayout_2011 = dict( geo=dict(scope='usa',showlakes=True,lakecolor='rgb(85,173,240)'),
                title='Cancer Rates in states in Year 2011')
myChoroMap_2011 = go.Figure(data=[plot2011_Pollution],layout=myLayout_2011)
iplot(myChoroMap_2011)
# Out:
# <div id="98a9907a-8860-4591-a6c3-bb5adc857c81" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("98a9907a-8860-4591-a6c3-bb5adc857c81", [{"type": "choropleth", "locations": ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SD", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY", "AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SD", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY", "AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SD", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY", "AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SD", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY", "AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SD", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY", "AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SD", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"], "locationmode": "USA-states", "colorscale": "YlOrRd_r", "text": [4240, 380, 3820, 2660, 17660, 2250, 2680, 780, 17150, 6410, 780, 870, 9210, 5520, 2480, 1990, 4860, 3630, 1400, 3960, 4970, 8140, 3340, 2430, 5470, 750, 1270, 1510, 1110, 6210, 980, 14200, 7300, 420, 10060, 3270, 2860, 10900, 880, 3900, 580, 5870, 13880, 630, 360, 400, 3090, 1480, 2940, 260], "z": [8.833484239, 5.2579654719999995, 5.906763136, 9.049179569, 4.687226996000001, 4.3959393239999995, 7.465403565, 8.591027443, 8.980490709, 6.533076631, 5.660936058, 5.491928443, 7.161735152, 8.470830878, 8.090765337, 6.934998847999999, 11.12292572, 7.933725634, 10.54033523, 6.776641055, 7.516723955, 8.242025562, 6.244669128, 8.159394956, 9.100411814, 7.516378187999999, 6.893620577999999, 5.554780993, 8.418829965, 7.0238992410000005, 4.716626976000001, 7.274765697, 7.5640120060000005, 6.1271291770000005, 8.713861727000001, 8.636458957, 7.39394281, 8.55284793, 8.361434404, 8.346464747999999, 7.035436767, 9.175266982, 5.412067952, 2.2371174, 5.74410033, 0.493216121, 4.529118273, 7.978557089, 5.149186288, 4.579682064], "marker": {"line": {"color": "rgb(255,255,255)", "width": 1}}, "colorbar": {"title": "Cancer Rates"}}], {"geo": {"scope": "usa", "showlakes": true, "lakecolor": "rgb(85,173,240)"}, "title": "Cancer Rates in states in Year 2011"}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
Year2011 = exportData.loc[exportData['year'] == 2011]

plot2011_Pollution = dict(type ='choropleth',
           locations = exportData['StateCode'],
           locationmode = 'USA-states',
           colorscale = 'YlOrRd_r',
#           text=Year2011['Lung_Cancer'],
           z = Year2011['Percentage of smokers number'],
           marker = dict(line=dict(color='rgb(255,255,255)',width=1)),
           colorbar = {'title':'Cancer Rates'})
myLayout_2011 = dict( geo=dict(scope='usa',showlakes=True,lakecolor='rgb(85,173,240)'),
                title='Percentage of smokers in Year 2011')
myChoroMap_2011 = go.Figure(data=[plot2011_Pollution],layout=myLayout_2011)
iplot(myChoroMap_2011)
# Out:
# <div id="629c5f08-8767-4f27-89a1-8cc01737f57a" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("629c5f08-8767-4f27-89a1-8cc01737f57a", [{"type": "choropleth", "locations": ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SD", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY", "AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SD", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY", "AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SD", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY", "AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SD", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY", "AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SD", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY", "AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SD", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"], "locationmode": "USA-states", "colorscale": "YlOrRd_r", "z": [24.3, 22.9, 19.3, 27.0, 13.7, 18.3, 17.1, 21.8, 19.3, 21.2, 16.8, 17.2, 20.9, 25.6, 20.4, 22.0, 29.0, 25.7, 22.8, 19.1, 18.2, 23.3, 19.1, 26.0, 25.0, 22.1, 20.0, 22.9, 19.4, 16.8, 21.5, 18.1, 21.8, 21.9, 25.1, 26.1, 19.7, 22.4, 20.0, 23.1, 23.0, 23.0, 19.2, 11.8, 19.1, 20.9, 17.5, 28.6, 20.9, 23.0], "marker": {"line": {"color": "rgb(255,255,255)", "width": 1}}, "colorbar": {"title": "Cancer Rates"}}], {"geo": {"scope": "usa", "showlakes": true, "lakecolor": "rgb(85,173,240)"}, "title": "Percentage of smokers in Year 2011"}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
Year2011 = exportData.loc[exportData['year'] == 2011]

plot2011_Pollution = dict(type ='choropleth',
           locations = exportData['StateCode'],
           locationmode = 'USA-states',
           colorscale = 'YlOrRd_r',
#           text=Year2011['Lung_Cancer'],
           z = Year2011['NO2'],
           marker = dict(line=dict(color='rgb(255,255,255)',width=1)),
           colorbar = {'title':'ppm'})
myLayout_2011 = dict( geo=dict(scope='usa',showlakes=True,lakecolor='rgb(85,173,240)'),
                title='Average NO2 per year in ppm')
myChoroMap_2011 = go.Figure(data=[plot2011_Pollution],layout=myLayout_2011)
iplot(myChoroMap_2011)



#NO2	O3	SO2	CO
# Out:
# <div id="0fa4ef73-9d96-4934-bf60-1b58edf43a05" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("0fa4ef73-9d96-4934-bf60-1b58edf43a05", [{"type": "choropleth", "locations": ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SD", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY", "AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SD", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY", "AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SD", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY", "AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SD", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY", "AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SD", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY", "AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SD", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"], "locationmode": "USA-states", "colorscale": "YlOrRd_r", "z": [14.95703546, 13.29873491, 16.61533601, 9.982133811, 12.28285151, 17.52649097, 8.533361105, 11.07123298, 5.3618695039999995, 13.38118529, 2.8897305510000004, 9.925650261, 12.11059417, 9.906356071, 7.359249987, 13.10077026, 8.749330457000001, 11.66570671, 5.592793518, 12.94889615, 18.52994434, 13.82920734, 7.521111348, 7.359249987, null, 9.644705093999999, null, 16.66588024, null, 21.03529215, null, 13.088026800000002, 9.995173923, 4.477427017, 14.71971055, 6.743543982, 9.13221409, 11.23837584, 5.383758894, null, 6.187938958999999, null, 10.37497184, 18.2019178, null, 7.9258999779999995, null, null, null, 4.168865708999999], "marker": {"line": {"color": "rgb(255,255,255)", "width": 1}}, "colorbar": {"title": "ppm"}}], {"geo": {"scope": "usa", "showlakes": true, "lakecolor": "rgb(85,173,240)"}, "title": "Average NO2 per year in ppm"}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
plot2011_Pollution = dict(type ='choropleth',
           locations = exportData['StateCode'],
           locationmode = 'USA-states',
           colorscale = 'YlOrRd_r',
#           text=Year2011['Lung_Cancer'],
           z = Year2011['SO2'],
           marker = dict(line=dict(color='rgb(255,255,255)',width=1)),
           colorbar = {'title':'Average SO2 per year in ppm'})
myLayout_2011 = dict( geo=dict(scope='usa',showlakes=True,lakecolor='rgb(85,173,240)'),
                title='Average SO2 per year in ppm')
myChoroMap_2011 = go.Figure(data=[plot2011_Pollution],layout=myLayout_2011)
iplot(myChoroMap_2011)
# Out:
# <div id="7ff2d51b-de97-4d53-9464-5e6e059ef6eb" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("7ff2d51b-de97-4d53-9464-5e6e059ef6eb", [{"type": "choropleth", "locations": ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SD", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY", "AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SD", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY", "AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SD", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY", "AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SD", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY", "AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SD", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY", "AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SD", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"], "locationmode": "USA-states", "colorscale": "YlOrRd_r", "z": [0.923326797, 1.07072871, 0.775924884, 1.365532536, 0.7093256440000001, 1.40749376, 0.9024359609999999, 1.226259099, 0.096444729, 0.893666758, 0.90962653, 0.7152670870000001, 2.4854753919999997, 1.3611319780000002, 0.496738846, 3.618949336, 0.564890284, 1.247419835, 0.814470365, 1.980993026, 1.248917209, 0.876858457, 0.892280796, 0.496738846, null, 0.635253729, null, 0.502221684, null, 1.955486425, null, 2.483608524, 0.570810545, 0.277065048, 4.610093957, 0.8421996270000001, 0.74255611, 2.136101484, 0.161707636, null, 0.433789508, null, 0.634463837, 0.957896375, null, 0.614728732, null, null, null, 0.164213624], "marker": {"line": {"color": "rgb(255,255,255)", "width": 1}}, "colorbar": {"title": "Average SO2 per year in ppm"}}], {"geo": {"scope": "usa", "showlakes": true, "lakecolor": "rgb(85,173,240)"}, "title": "Average SO2 per year in ppm"}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
Year2011 = exportData.loc[exportData['year'] == 2011]

plot2011_Pollution = dict(type ='choropleth',
           locations = exportData['StateCode'],
           locationmode = 'USA-states',
           colorscale = 'YlOrRd_r',
#           text=Year2011['Lung_Cancer'],
           z = Year2011['O3'],
           marker = dict(line=dict(color='rgb(255,255,255)',width=1)),
           colorbar = {'title':'Average O3 per year in ppm'})
myLayout_2011 = dict( geo=dict(scope='usa',showlakes=True,lakecolor='rgb(85,173,240)'),
                title='Average O3 per year in ppm')
myChoroMap_2011 = go.Figure(data=[plot2011_Pollution],layout=myLayout_2011)
iplot(myChoroMap_2011)
# Out:
# <div id="34fb1cb5-6a0f-4ed4-8d03-b032414b6ee3" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("34fb1cb5-6a0f-4ed4-8d03-b032414b6ee3", [{"type": "choropleth", "locations": ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SD", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY", "AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SD", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY", "AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SD", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY", "AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SD", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY", "AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SD", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY", "AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SD", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"], "locationmode": "USA-states", "colorscale": "YlOrRd_r", "z": [0.026975053, 0.027137129, 0.026812976000000002, 0.027461282000000004, 0.026144162999999998, 0.027845388, 0.028971219, 0.024982754, 0.028131008, 0.022986242, 0.027078976, 0.012998609, 0.024866725, 0.03377056, 0.028032132, 0.021984429, 0.023459876, 0.025233942000000002, 0.024528900000000003, 0.026296115, 0.020850772, 0.030609082000000003, 0.027551159, 0.028032132, null, 0.023653811, null, 0.026886372999999998, null, 0.022285983, null, 0.025910588, 0.029280112999999997, 0.025588099, 0.024950752000000003, 0.03581865, 0.018564716999999998, 0.024840284, 0.030741, null, 0.030389317000000002, null, 0.027571724, 0.027011418, null, 0.033163537, null, null, null, 0.037890191000000004], "marker": {"line": {"color": "rgb(255,255,255)", "width": 1}}, "colorbar": {"title": "Average O3 per year in ppm"}}], {"geo": {"scope": "usa", "showlakes": true, "lakecolor": "rgb(85,173,240)"}, "title": "Average O3 per year in ppm"}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
Year2011 = exportData.loc[exportData['year'] == 2011]

plot2011_Pollution = dict(type ='choropleth',
           locations = exportData['StateCode'],
           locationmode = 'USA-states',
           colorscale = 'YlOrRd_r',
#           text=Year2011['Lung_Cancer'],
           z = Year2011['CO'],
           marker = dict(line=dict(color='rgb(255,255,255)',width=1)),
           colorbar = {'title':'Average CO per year in ppm'})
myLayout_2011 = dict( geo=dict(scope='usa',showlakes=True,lakecolor='rgb(85,173,240)'),
                title='Average CO per year in ppm')
myChoroMap_2011 = go.Figure(data=[plot2011_Pollution],layout=myLayout_2011)
iplot(myChoroMap_2011)
# Out:
# <div id="92dc6ccb-aa5b-4033-a41b-c0926b7d39aa" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("92dc6ccb-aa5b-4033-a41b-c0926b7d39aa", [{"type": "choropleth", "locations": ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SD", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY", "AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SD", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY", "AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SD", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY", "AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SD", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY", "AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SD", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY", "AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SD", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"], "locationmode": "USA-states", "colorscale": "YlOrRd_r", "z": [0.36935055899999997, 0.395275948, 0.34342517, 0.447126725, 0.36051701, 0.332982973, 0.221253444, 0.247302065, 0.43369493, 0.33172545, 0.316353199, 0.272311457, 0.340223107, 0.056329454, 0.20670481100000002, 0.451442347, 0.24512800899999998, 0.22149750399999998, 0.23271899899999998, 0.300602423, 0.288049269, 0.272120885, 0.21467512, 0.20670481100000002, null, 0.204016287, null, 0.295885974, null, 0.358829825, null, 0.277630808, 0.33896941399999997, 0.165147266, 0.284705544, 0.228100678, 0.336895571, 0.231960903, 0.190794102, null, 0.19053938899999998, null, 0.19842678800000002, 0.34607531700000005, null, 0.289209822, null, null, null, 0.123082884], "marker": {"line": {"color": "rgb(255,255,255)", "width": 1}}, "colorbar": {"title": "Average CO per year in ppm"}}], {"geo": {"scope": "usa", "showlakes": true, "lakecolor": "rgb(85,173,240)"}, "title": "Average CO per year in ppm"}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>
