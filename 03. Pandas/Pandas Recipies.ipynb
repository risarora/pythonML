# %% [markdown]
# 1.	Dissecting the anatomy of a DataFrame
# 2.	Accessing the main DataFrame components
# 3.	Understanding data types
# 4.	Selecting a single column of data as a Series
# 5.	Calling Series methods
# 6.	Working with operators on a Series
# 7.	Chaining Series methods together
# 8.	Making the index meaningful
# 9.	Renaming row and column names
# 10.	Creating and deleting columns
# 11.	Essential DataFrame Operations
# 12.	Selecting multiple DataFrame columns
# 13.	Selecting columns with methods
# 14.	Ordering column names sensibly
# 15.	Operating on the entire DataFrame
# 16.	Chaining DataFrame methods together
# 17.	Working with operators on a DataFrame
# 18.	Comparing missing values
# 19.	Transposing the direction of a DataFrame operation
# 20.	Determining college campus diversity
# 21.	Beginning Data Analysis
# 22.	Developing a data analysis routine
# 23.	Data dictionaries
# 24.	Reducing memory by changing data types
# 25.	Selecting the smallest of the largest
# 26.	Selecting the largest of each group by sorting
# 27.	Replicating nlargest with sort_values
# 28.	Calculating a trailing stop order price
# 29.	Selecting Subsets of Data
# 30.	Selecting Series data
# 31.	Selecting DataFrame rows
# 32.	Selecting DataFrame rows and columns simultaneously
# 33.	Selecting data with both integers and labels
# 34.	Speeding up scalar selection
# 35.	Slicing rows lazily
# 36.	Slicing lexicographically
# 37.	Boolean Indexing
# 38.	Calculating boolean statistics
# 39.	Constructing multiple boolean conditions
# 40.	Filtering with boolean indexing
# 41.	Replicating boolean indexing with index selection
# 42.	Selecting with unique and sorted indexes
# 43.	Gaining perspective on stock prices
# 44.	Translating SQL WHERE clauses
# 45.	Determining the normality of stock market returns
# 46.	Improving readability of boolean indexing with the query method
# 47.	Preserving Series with the where method
# 48.	Masking DataFrame rows
# 49.	Selecting with booleans, integer location, and labels
# 50.	Index Alignment
# 51.	Examining the Index object
# 52.	Producing Cartesian products
# 53.	Exploding indexes
# 54.	Filling values with unequal indexes
# 55.	Appending columns from different DataFrames
# 56.	Highlighting the maximum value from each column
# 57.	Replicating idxmax with method chaining
# 58.	Finding the most common maximum
# 59.	Grouping for Aggregation, Filtration, and Transformation
# 60.	Defining an aggregation
# 61.	Grouping and aggregating with multiple columns and functions
# 62.	Removing the MultiIndex after grouping
# 63.	Customizing an aggregation function
# 64.	Customizing aggregating functions with *args and **kwargs
# 65.	Examining the groupby object
# 66.	Filtering for states with a minority majority
# 67.	Transforming through a weight loss bet
# 68.	Calculating weighted mean SAT scores per state with apply
# 69.	Grouping by continuous variables
# 70.	Counting the total number of flights between cities
# 71.	Finding the longest streak of on-time flights
# 72.	Restructuring Data into a Tidy Form
# 73.	Tidying variable values as column names with stack
# 74.	Tidying variable values as column names with melt
# 75.	Stacking multiple groups of variables simultaneously
# 76.	Inverting stacked data
# 77.	Unstacking after a groupby aggregation
# 78.	Replicating pivot_table with a groupby aggregation
# 79.	Renaming axis levels for easy reshaping
# 80.	Tidying when multiple variables are stored as column names
# 81.	Getting ready...
# 82.	Tidying when multiple variables are stored as column values
# 83.	Tidying when two or more values are stored in the same cell
# 84.	Tidying when variables are stored in column names and values
# 85.	Tidying when multiple observational units are stored in the same table
# 86.	Combining Pandas Objects
# 87.	Appending new rows to DataFrames
# 88.	Concatenating multiple DataFrames together
# 89.	Comparing President Trump's and Obama's approval ratings
# 90.	Understanding the differences between concat, join, and merge
# 91.	Connecting to SQL databases
# 92.	Time Series Analysis
# 93.	Understanding the difference between Python and pandas date tools
# 94.	Slicing time series intelligently
# 95.	Using methods that only work with a DatetimeIndex
# 96.	Counting the number of weekly crimes
# 97.	Aggregating weekly crime and traffic accidents separately
# 98.	Measuring crime by weekday and year
# 99.	Grouping with anonymous functions with a DatetimeIndex
# 100.	Grouping by a Timestamp and another column
# 101.	Finding the last time crime was 20% lower with merge_asof
# 102.	Visualization with Matplotlib, Pandas, and Seaborn
# 103.	Getting started with matplotlib
# 104.	Object-oriented guide to matplotlib
# 105.	Visualizing data with matplotlib
# 106.	Plotting basics with pandas
# 107.	Visualizing the flights dataset
# 108.	Stacking area charts to discover emerging trends
# 109.	Understanding the differences between seaborn and pandas
# 110.	Doing multivariate analysis with seaborn Grids
# 111.	Uncovering Simpson's paradox in the diamonds dataset with seaborn
