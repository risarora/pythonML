# %% [markdown]
# Install matplotlib
#
#     conda install matploylib

# %% [markdown]
# ##### Offical Matplotlib reference page
#
# https://matplotlib.org/gallery/index.html

# %%
import matplotlib.pyplot as plt

# %%
# Used to get the output of the matplotlib within jupyter notebooks
# %matplotlib inline

# %%
import numpy as np

# %%
x = np.linspace(0,5,11)
y=x*x

# %%
x
# Out:
# array([ 0. ,  0.5,  1. ,  1.5,  2. ,  2.5,  3. ,  3.5,  4. ,  4.5,  5. ])

# %%
y
# Out:
# array([  0.  ,   0.25,   1.  ,   2.25,   4.  ,   6.25,   9.  ,  12.25,
#         16.  ,  20.25,  25.  ])

# %%
plt.plot(x,y)
plt.xlabel('X Label')
plt.ylabel('Y Label')
plt.title('Title')
#plt.show()

# %%
# Using sub plots

plt.subplot(1,2,1)
plt.plot(x,y,'r')

plt.subplot(1,2,2)
plt.plot(y,x,'b')

# %% [markdown]
# Object oriented method

# %%
# OO
fig = plt.figure()
axes = fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(x,y)
axes.set_ylabel('Y Label')
axes.set_xlabel('X Label')
axes.set_title('Title')

# %% [markdown]
# #### Insert Plots

# %%
fig = plt.figure()
axes = fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(x,y,'r')
axes.set_xlabel('X Label')
axes.set_ylabel('Y Label')
axes.set_title('Title Outer ')

axes = fig.add_axes([0.6,0.1,0.3,0.25])
axes.plot(x,y)
axes.set_ylabel('Y Label')
axes.set_xlabel('X Label')
axes.set_title('Title Inner')

# %%
fig = plt.figure()
outerAxes = fig.add_axes([0.1,0.1,0.8,0.8])
innerAxes = fig.add_axes([0.6,0.1,0.3,0.25])

outerAxes.plot(x,y,'r')
outerAxes.set_xlabel('X Label')
outerAxes.set_ylabel('Y Label')
outerAxes.set_title('Title Outer ')

innerAxes.plot(x,y)
innerAxes.set_ylabel('Y Label')
innerAxes.set_xlabel('X Label')
innerAxes.set_title('Title Inner')

# %%
fig = plt.figure()
axes = fig.add_axes([0.0,0.0,1,1])
axes.plot(x,y,'r')
axes.set_title('Outer Title')
axes = fig.add_axes([0.0,0.7,0.4,0.25])
axes.plot(x,y,'r')

# %% [markdown]
# # Create Sub Plots

# %% [raw]
# Iterate the subplots

# %%
fig,axes = plt.subplots(nrows=1,ncols=2)
plt.tight_layout()

for current_ax in axes:
    current_ax.plot(x,y)
#axes.plt(x,y)

# %%
fig,axes = plt.subplots(nrows=1,ncols=2)
plt.tight_layout()

axes[0].plot(x,y)
axes[1].plot(x,y)

# %% [markdown]
# ### Figure Size and DPI

# %%
fig = plt.figure(figsize=(8,2))
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
fig,axes = plt.subplots(nrows=2,ncols=1,figsize=(8,2))
#ax = fig.add_axes([0,0,1,1])
axes[0].plot(x,y)
axes[1].plot(y,x)
#axes[2].plt(x,y)

# %%
fig.savefig('my_picture.jpeg',dpi=200)

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,x**2,label='X Squared')
ax.plot(x,x**3,label='X Cubbed')
ax.legend(loc=(0.02,0.8)) # Using Location Coordinates
#ax.legend(loc=0) # Using Location Code

# %%
fig=plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x ,y ,
            color='#aabbaa',
            lw =2,
            ls='-',
            marker='o',
            markersize='4')

# %% [markdown]
# ### Plot Range

# %%
y=x**2

y1 = y + 2
y2 = y + 5

# %%
fig=plt.figure()
ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0,0,1,1])
ax1.plot(x ,y1 ,color='#aabbaa',lw =2,ls='-',marker='o',markersize='4')
ax2.plot(x ,y2 ,'r--o')

ax1.set_xlim()
ax1.set_ylim(10,40)
ax2.set_xlim()
ax2.set_ylim(0,12)
# Out:
# (0, 12)

# %%
plt.scatter(x,y1)

# %% [markdown]
# https://stackoverflow.com/questions/3584805/in-matplotlib-what-does-the-argument-mean-in-fig-add-subplot111
